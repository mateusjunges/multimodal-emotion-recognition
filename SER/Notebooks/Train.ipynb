# %% [markdown]
# # Speech Emotion Recognition - Time Distributed ConvNet

# %% [markdown]
# ## I. Context
# In this project I build a prevision model using deep learning combining **CNN**  and  **LSTM**  to detect a person’s emotions (HAPPY, SAD, FEAR, ANGRY, DISGUST, SURPRISE, NEUTRAL) just by their voice.
#
# ### Audio features:
# - **Log-mel-spectrogram**: the mel-frequency cepstrum (MFC) is a representation of the short-term power spectrum of a sound, based on a linear cosine transform of a log power spectrum on a nonlinear mel scale of frequency
#
#
# ### Data:
# - **RAVDESS**: The Ryerson Audio-Visual Database of Emotional Speech and Song (RAVDESS) contains 7356 files (total size: 24.8 GB). The database contains 24 professional actors (12 female, 12 male), vocalizing two lexically-matched statements in a neutral North American accent. Speech includes *calm*, *happy*, *sad*, *angry*, *fearful*, *surprise*, and *disgust* expressions, and song contains calm, happy, sad, angry, and fearful emotions. Each expression is produced at two levels of emotional intensity (normal, strong), with an additional neutral expression. (https://zenodo.org/record/1188976#.XA48aC17Q1J)

# %% [markdown]
# ## II. General Imports

# %%
### General imports ###
import os
from glob import glob
import pickle
import numpy as np

### Plot imports ###
from IPython.display import Image
import matplotlib.pyplot as plt

### Time Distributed ConvNet imports ###
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Dropout, Activation, TimeDistributed, concatenate
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, BatchNormalization, LeakyReLU, Flatten
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import backend as K
from keras.utils import np_utils
from keras.utils import plot_model
from sklearn.preprocessing import LabelEncoder

### Warning ###
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## III. Import datas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
base_path = '/content/drive/My Drive/UEPG/eng-comp/5-ano/tcc-v2/'

# %%
# RAVDESS mel-Spectrogram
X_train = pickle.load(open(base_path + 'features-from-extracted-audios/x_train.p', 'rb'))
y_train = pickle.load(open(base_path + 'features-from-extracted-audios/y_train.p', 'rb'))
y_test = pickle.load(open(base_path + 'features-from-extracted-audios/y_test.p', 'rb'))
X_test = pickle.load(open(base_path + 'features-from-extracted-audios/x_test.p', 'rb'))

# %% [markdown]
# ## IV. Encode label

# %%
# Encode Label from categorical to numerical
lb = LabelEncoder()
y_train = np_utils.to_categorical(lb.fit_transform(np.ravel(y_train)))
y_test = np_utils.to_categorical(lb.transform(np.ravel(y_test)))

# %% [markdown]
# ## V. Reshape train and test set

# %%
# Reshape for convolution
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1] , X_train.shape[2], X_train.shape[3], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1] , X_test.shape[2], X_test.shape[3], 1)

# %% [markdown]
# ## VI. Time Distributed ConvNet model

# %%
K.clear_session()

# Define two sets of inputs: MFCC and FBANK
input_y = Input(shape=X_train.shape[1:], name='Input_MELSPECT')

## First LFLB (local feature learning block)
y = TimeDistributed(Conv2D(64, kernel_size=(3, 3), strides=(1, 1), padding='same'))(input_y)
y = TimeDistributed(BatchNormalization())(y)
y = TimeDistributed(Activation('elu'))(y)
y = TimeDistributed(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='same'))(y)
y = TimeDistributed(Dropout(0.2))(y)     

## Second LFLB (local feature learning block)
y = TimeDistributed(Conv2D(64, kernel_size=(3, 3), strides=(1, 1), padding='same'))(y)
y = TimeDistributed(BatchNormalization())(y)
y = TimeDistributed(Activation('elu'))(y)
y = TimeDistributed(MaxPooling2D(pool_size=(4, 4), strides=(4, 4), padding='same'))(y)
y = TimeDistributed(Dropout(0.2))(y)

## Second LFLB (local feature learning block)
y = TimeDistributed(Conv2D(128, kernel_size=(3, 3), strides=(1, 1), padding='same'))(y)
y = TimeDistributed(BatchNormalization())(y)
y = TimeDistributed(Activation('elu'))(y)
y = TimeDistributed(MaxPooling2D(pool_size=(4, 4), strides=(4, 4), padding='same'))(y)
y = TimeDistributed(Dropout(0.2))(y)

## Second LFLB (local feature learning block)
y = TimeDistributed(Conv2D(128, kernel_size=(3, 3), strides=(1, 1), padding='same'))(y)
y = TimeDistributed(BatchNormalization())(y)
y = TimeDistributed(Activation('elu'))(y)
y = TimeDistributed(MaxPooling2D(pool_size=(4, 4), strides=(4, 4), padding='same'))(y)
y = TimeDistributed(Dropout(0.2))(y)  

## Flat
y = TimeDistributed(Flatten())(y)                      
                               
# Apply 2 LSTM layer and one FC
y = LSTM(256, return_sequences=False, dropout=0.2)(y)
y = Dense(y_train.shape[1], activation='softmax', name='FC')(y)

# Build final model
model = Model(inputs=input_y, outputs=y)

# Plot model graph
plot_model(model, show_shapes=True, show_layer_names=True, to_file=base_path + 'model.png')
Image(retina=True, filename=base_path + 'model.png')

# %%
# Compile model
model.compile(optimizer=SGD(lr=0.01, decay=1e-6, momentum=0.8), loss='categorical_crossentropy', metrics=['accuracy'])

# Save best model
best_model_save = ModelCheckpoint(base_path + 'best_model.hdf5', save_best_only=True, monitor='val_accuracy', mode='max')

# Early stopping
early_stopping = EarlyStopping(monitor='val_accuracy', patience=30, verbose=1, mode='max')

# Fit model
history = model.fit(X_train, y_train, batch_size=64, epochs=100, validation_data=(X_test, y_test), callbacks=[early_stopping, best_model_save])
# Out:
# Epoch 1/100
# 51/51 [==============================] - 11s 222ms/step - loss: 1.9443 - accuracy: 0.1895 - val_loss: 2.1597 - val_accuracy: 0.1190
# Epoch 2/100
# 51/51 [==============================] - 10s 202ms/step - loss: 1.8240 - accuracy: 0.2611 - val_loss: 2.0803 - val_accuracy: 0.1599
# Epoch 3/100
# 51/51 [==============================] - 11s 213ms/step - loss: 1.7170 - accuracy: 0.3175 - val_loss: 1.8449 - val_accuracy: 0.2639
# Epoch 4/100
# 51/51 [==============================] - 11s 211ms/step - loss: 1.6444 - accuracy: 0.3501 - val_loss: 1.7120 - val_accuracy: 0.3123
# Epoch 5/100
# 51/51 [==============================] - 11s 211ms/step - loss: 1.6060 - accuracy: 0.3538 - val_loss: 1.6461 - val_accuracy: 0.3234
# Epoch 6/100
# 51/51 [==============================] - 11s 212ms/step - loss: 1.5711 - accuracy: 0.3684 - val_loss: 1.5427 - val_accuracy: 0.4015
# Epoch 7/100
# 51/51 [==============================] - 11s 212ms/step - loss: 1.5525 - accuracy: 0.3805 - val_loss: 1.5123 - val_accuracy: 0.4201
# Epoch 8/100
# 51/51 [==============================] - 11s 211ms/step - loss: 1.5043 - accuracy: 0.4084 - val_loss: 1.4730 - val_accuracy: 0.4684
# Epoch 9/100
# 51/51 [==============================] - 10s 200ms/step - loss: 1.4713 - accuracy: 0.4198 - val_loss: 1.4342 - val_accuracy: 0.4535
# Epoch 10/100
# 51/51 [==============================] - 10s 200ms/step - loss: 1.4426 - accuracy: 0.4347 - val_loss: 1.4850 - val_accuracy: 0.4387
# Epoch 11/100
# 51/51 [==============================] - 10s 200ms/step - loss: 1.4240 - accuracy: 0.4431 - val_loss: 1.6773 - val_accuracy: 0.3755
# Epoch 12/100
# 51/51 [==============================] - 10s 200ms/step - loss: 1.3767 - accuracy: 0.4589 - val_loss: 1.6481 - val_accuracy: 0.3643
# Epoch 13/100
# 51/51 [==============================] - 11s 212ms/step - loss: 1.3550 - accuracy: 0.4760 - val_loss: 1.3739 - val_accuracy: 0.4870
# Epoch 14/100
# 51/51 [==============================] - 10s 200ms/step - loss: 1.3289 - accuracy: 0.4865 - val_loss: 2.0242 - val_accuracy: 0.3086
# Epoch 15/100
# 51/51 [==============================] - 10s 201ms/step - loss: 1.2814 - accuracy: 0.5051 - val_loss: 1.4180 - val_accuracy: 0.4610
# Epoch 16/100
# 51/51 [==============================] - 10s 200ms/step - loss: 1.2750 - accuracy: 0.5005 - val_loss: 1.4066 - val_accuracy: 0.4684
# Epoch 17/100
# 51/51 [==============================] - 10s 200ms/step - loss: 1.2297 - accuracy: 0.5318 - val_loss: 1.5668 - val_accuracy: 0.4164
# Epoch 18/100
# 51/51 [==============================] - 10s 200ms/step - loss: 1.2367 - accuracy: 0.5222 - val_loss: 1.5436 - val_accuracy: 0.4758
# Epoch 19/100
# 51/51 [==============================] - 10s 200ms/step - loss: 1.1966 - accuracy: 0.5501 - val_loss: 1.4212 - val_accuracy: 0.4387
# Epoch 20/100
# 51/51 [==============================] - 10s 200ms/step - loss: 1.1771 - accuracy: 0.5529 - val_loss: 1.5573 - val_accuracy: 0.4498
# Epoch 21/100
# 51/51 [==============================] - 10s 200ms/step - loss: 1.1538 - accuracy: 0.5674 - val_loss: 1.7186 - val_accuracy: 0.3978
# Epoch 22/100
# 51/51 [==============================] - 10s 200ms/step - loss: 1.1144 - accuracy: 0.5746 - val_loss: 1.3463 - val_accuracy: 0.4535
# Epoch 23/100
# 51/51 [==============================] - 10s 200ms/step - loss: 1.1121 - accuracy: 0.5761 - val_loss: 1.3964 - val_accuracy: 0.4387
# Epoch 24/100
# 51/51 [==============================] - 10s 200ms/step - loss: 1.0776 - accuracy: 0.5901 - val_loss: 2.0744 - val_accuracy: 0.3643
# Epoch 25/100
# 51/51 [==============================] - 11s 213ms/step - loss: 1.0251 - accuracy: 0.6071 - val_loss: 1.3494 - val_accuracy: 0.5093
# Epoch 26/100
# 51/51 [==============================] - 11s 211ms/step - loss: 1.0245 - accuracy: 0.6050 - val_loss: 1.3108 - val_accuracy: 0.5353
# Epoch 27/100
# 51/51 [==============================] - 11s 213ms/step - loss: 1.0041 - accuracy: 0.6155 - val_loss: 1.3859 - val_accuracy: 0.5502
# Epoch 28/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.9867 - accuracy: 0.6236 - val_loss: 1.2842 - val_accuracy: 0.5502
# Epoch 29/100
# 51/51 [==============================] - 11s 211ms/step - loss: 0.9613 - accuracy: 0.6366 - val_loss: 1.1259 - val_accuracy: 0.5874
# Epoch 30/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.9609 - accuracy: 0.6384 - val_loss: 1.3567 - val_accuracy: 0.5390
# Epoch 31/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.9468 - accuracy: 0.6403 - val_loss: 1.1661 - val_accuracy: 0.5836
# Epoch 32/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.9371 - accuracy: 0.6409 - val_loss: 1.2307 - val_accuracy: 0.5836
# Epoch 33/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.9213 - accuracy: 0.6481 - val_loss: 1.6125 - val_accuracy: 0.5093
# Epoch 34/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.9117 - accuracy: 0.6509 - val_loss: 1.1240 - val_accuracy: 0.5836
# Epoch 35/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.8949 - accuracy: 0.6580 - val_loss: 1.4144 - val_accuracy: 0.5204
# Epoch 36/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.8938 - accuracy: 0.6598 - val_loss: 1.3458 - val_accuracy: 0.5613
# Epoch 37/100
# 51/51 [==============================] - 11s 211ms/step - loss: 0.8586 - accuracy: 0.6750 - val_loss: 0.9572 - val_accuracy: 0.6431
# Epoch 38/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.8525 - accuracy: 0.6896 - val_loss: 1.3575 - val_accuracy: 0.5502
# Epoch 39/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.8287 - accuracy: 0.6912 - val_loss: 0.9987 - val_accuracy: 0.6431
# Epoch 40/100
# 51/51 [==============================] - 10s 201ms/step - loss: 0.8234 - accuracy: 0.6902 - val_loss: 0.9535 - val_accuracy: 0.6431
# Epoch 41/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.7899 - accuracy: 0.7067 - val_loss: 1.3175 - val_accuracy: 0.5428
# Epoch 42/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.7997 - accuracy: 0.6992 - val_loss: 1.6892 - val_accuracy: 0.4944
# Epoch 43/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.7813 - accuracy: 0.7076 - val_loss: 0.9827 - val_accuracy: 0.6431
# Epoch 44/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.7633 - accuracy: 0.7085 - val_loss: 1.0031 - val_accuracy: 0.6245
# Epoch 45/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.7577 - accuracy: 0.7172 - val_loss: 1.1150 - val_accuracy: 0.6134
# Epoch 46/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.7386 - accuracy: 0.7324 - val_loss: 1.3484 - val_accuracy: 0.6022
# Epoch 47/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.7229 - accuracy: 0.7318 - val_loss: 1.0717 - val_accuracy: 0.6245
# Epoch 48/100
# 51/51 [==============================] - 10s 199ms/step - loss: 0.7202 - accuracy: 0.7330 - val_loss: 1.2034 - val_accuracy: 0.6022
# Epoch 49/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.7179 - accuracy: 0.7287 - val_loss: 1.1603 - val_accuracy: 0.5911
# Epoch 50/100
# 51/51 [==============================] - 11s 212ms/step - loss: 0.6848 - accuracy: 0.7429 - val_loss: 0.9106 - val_accuracy: 0.6691
# Epoch 51/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.6915 - accuracy: 0.7414 - val_loss: 1.3165 - val_accuracy: 0.5799
# Epoch 52/100
# 51/51 [==============================] - 10s 199ms/step - loss: 0.6746 - accuracy: 0.7541 - val_loss: 1.3017 - val_accuracy: 0.5985
# Epoch 53/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.6564 - accuracy: 0.7560 - val_loss: 1.3931 - val_accuracy: 0.5948
# Epoch 54/100
# 51/51 [==============================] - 11s 212ms/step - loss: 0.6584 - accuracy: 0.7547 - val_loss: 0.9236 - val_accuracy: 0.6729
# Epoch 55/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.6277 - accuracy: 0.7640 - val_loss: 1.1440 - val_accuracy: 0.6543
# Epoch 56/100
# 51/51 [==============================] - 10s 199ms/step - loss: 0.6161 - accuracy: 0.7699 - val_loss: 1.6118 - val_accuracy: 0.5465
# Epoch 57/100
# 51/51 [==============================] - 11s 211ms/step - loss: 0.5999 - accuracy: 0.7699 - val_loss: 0.8160 - val_accuracy: 0.7138
# Epoch 58/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.5838 - accuracy: 0.7876 - val_loss: 1.1091 - val_accuracy: 0.6654
# Epoch 59/100
# 51/51 [==============================] - 10s 199ms/step - loss: 0.6134 - accuracy: 0.7668 - val_loss: 1.1684 - val_accuracy: 0.6431
# Epoch 60/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.5703 - accuracy: 0.7935 - val_loss: 1.1839 - val_accuracy: 0.6022
# Epoch 61/100
# 51/51 [==============================] - 10s 199ms/step - loss: 0.5950 - accuracy: 0.7771 - val_loss: 0.8462 - val_accuracy: 0.6989
# Epoch 62/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.5569 - accuracy: 0.7854 - val_loss: 0.8501 - val_accuracy: 0.7100
# Epoch 63/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.5415 - accuracy: 0.8053 - val_loss: 1.0116 - val_accuracy: 0.7063
# Epoch 64/100
# 51/51 [==============================] - 10s 199ms/step - loss: 0.5373 - accuracy: 0.8028 - val_loss: 2.2123 - val_accuracy: 0.4647
# Epoch 65/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.5276 - accuracy: 0.7932 - val_loss: 1.3782 - val_accuracy: 0.6022
# Epoch 66/100
# 51/51 [==============================] - 11s 213ms/step - loss: 0.5261 - accuracy: 0.8000 - val_loss: 0.8387 - val_accuracy: 0.7323
# Epoch 67/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.4867 - accuracy: 0.8223 - val_loss: 2.5745 - val_accuracy: 0.4461
# Epoch 68/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.5009 - accuracy: 0.8074 - val_loss: 0.8628 - val_accuracy: 0.7175
# Epoch 69/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.5120 - accuracy: 0.8121 - val_loss: 0.9502 - val_accuracy: 0.6691
# Epoch 70/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.4908 - accuracy: 0.8136 - val_loss: 1.5479 - val_accuracy: 0.5613
# Epoch 71/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.4810 - accuracy: 0.8192 - val_loss: 0.9427 - val_accuracy: 0.6729
# Epoch 72/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.4578 - accuracy: 0.8279 - val_loss: 0.8364 - val_accuracy: 0.7323
# Epoch 73/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.4351 - accuracy: 0.8381 - val_loss: 0.7694 - val_accuracy: 0.7286
# Epoch 74/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.4424 - accuracy: 0.8375 - val_loss: 1.0953 - val_accuracy: 0.6431
# Epoch 75/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.4401 - accuracy: 0.8350 - val_loss: 1.0582 - val_accuracy: 0.6989
# Epoch 76/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.4240 - accuracy: 0.8397 - val_loss: 1.2293 - val_accuracy: 0.6506
# Epoch 77/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.4383 - accuracy: 0.8363 - val_loss: 0.8676 - val_accuracy: 0.7138
# Epoch 78/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.4347 - accuracy: 0.8363 - val_loss: 0.9816 - val_accuracy: 0.6989
# Epoch 79/100
# 51/51 [==============================] - 10s 199ms/step - loss: 0.4093 - accuracy: 0.8462 - val_loss: 1.2974 - val_accuracy: 0.6134
# Epoch 80/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.3993 - accuracy: 0.8518 - val_loss: 1.2078 - val_accuracy: 0.6803
# Epoch 81/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.3956 - accuracy: 0.8546 - val_loss: 1.5513 - val_accuracy: 0.6022
# Epoch 82/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.3701 - accuracy: 0.8623 - val_loss: 1.1732 - val_accuracy: 0.6691
# Epoch 83/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.3609 - accuracy: 0.8682 - val_loss: 1.1359 - val_accuracy: 0.6729
# Epoch 84/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.3608 - accuracy: 0.8732 - val_loss: 1.1568 - val_accuracy: 0.6840
# Epoch 85/100
# 51/51 [==============================] - 11s 213ms/step - loss: 0.3421 - accuracy: 0.8735 - val_loss: 0.8493 - val_accuracy: 0.7361
# Epoch 86/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.3702 - accuracy: 0.8633 - val_loss: 1.1308 - val_accuracy: 0.6543
# Epoch 87/100
# 51/51 [==============================] - 10s 199ms/step - loss: 0.3544 - accuracy: 0.8707 - val_loss: 0.9379 - val_accuracy: 0.7100
# Epoch 88/100
# 51/51 [==============================] - 10s 199ms/step - loss: 0.3390 - accuracy: 0.8769 - val_loss: 1.6331 - val_accuracy: 0.5985
# Epoch 89/100
# 51/51 [==============================] - 11s 212ms/step - loss: 0.3504 - accuracy: 0.8722 - val_loss: 0.8783 - val_accuracy: 0.7546
# Epoch 90/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.3284 - accuracy: 0.8788 - val_loss: 1.4082 - val_accuracy: 0.6320
# Epoch 91/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.3150 - accuracy: 0.8812 - val_loss: 1.0632 - val_accuracy: 0.6914
# Epoch 92/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.2859 - accuracy: 0.8946 - val_loss: 0.8850 - val_accuracy: 0.7175
# Epoch 93/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.2938 - accuracy: 0.8933 - val_loss: 0.9669 - val_accuracy: 0.7323
# Epoch 94/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.2873 - accuracy: 0.8971 - val_loss: 1.1165 - val_accuracy: 0.6803
# Epoch 95/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.2718 - accuracy: 0.8980 - val_loss: 0.9854 - val_accuracy: 0.7323
# Epoch 96/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.2826 - accuracy: 0.9020 - val_loss: 1.0619 - val_accuracy: 0.7249
# Epoch 97/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.2694 - accuracy: 0.9060 - val_loss: 1.2185 - val_accuracy: 0.6617
# Epoch 98/100
# 51/51 [==============================] - 11s 213ms/step - loss: 0.2631 - accuracy: 0.9023 - val_loss: 0.7270 - val_accuracy: 0.7695
# Epoch 99/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.2538 - accuracy: 0.9098 - val_loss: 0.9491 - val_accuracy: 0.7546
# Epoch 100/100
# 51/51 [==============================] - 10s 200ms/step - loss: 0.2605 - accuracy: 0.9113 - val_loss: 1.1855 - val_accuracy: 0.6617

# %%
# Loss Curves
plt.figure(figsize=(25, 10))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'],'b',linewidth=2.0)
plt.plot(history.history['val_loss'],'r',linewidth=2.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=14)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=22)
 
# Accuracy Curves
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'],'b',linewidth=2.0)
plt.plot(history.history['val_accuracy'],'r',linewidth=2.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=14)
plt.xlabel('Epochs ',fontsize=16)

plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=22)
plt.show()

# %% [markdown]
# ## VII. Save model

# %%
model.save(base_path + 'model.h5')
model.save_weights(base_path + 'model-weights.h5')
